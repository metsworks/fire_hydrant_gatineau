# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect("dbname=Borne user=postgres host=localhost password=@bb93_26postgres")
df = pd.read_sql("SELECT * FROM v_map_points_simple", conn)
df.to_csv("v_map_points_simple.csv", index=False)
conn.close()
# Out:
# C:\Users\metsw\AppData\Local\Temp\ipykernel_35252\4080478794.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM v_map_points_simple", conn)

# %%
df = pd.read_csv("v_map_points_simple.csv")

# %%
df
# Out:
#         adresseid         adresse_complete type_point  longitude   latitude
# 0             197        88 Rue de Lacaune    Adresse -75.720493  45.489893
# 1             198       115 Rue de Lacaune    Adresse -75.721708  45.490631
# 2             199       112 Rue de Lacaune    Adresse -75.721607  45.490147
# 3             200       111 Rue de Lacaune    Adresse -75.721519  45.490596
# 4             282        87 Rue de Lacaune    Adresse -75.720391  45.490386
# ...           ...                      ...        ...        ...        ...
# 345498      99808  1721(3) Rue Saint-Louis      Borne -75.723148  45.465320
# 345499      99808  1721(3) Rue Saint-Louis      Borne -75.723960  45.464412
# 345500      99804  1723(3) Rue Saint-Louis      Borne -75.724315  45.465450
# 345501      99804  1723(3) Rue Saint-Louis      Borne -75.723148  45.465320
# 345502      99804  1723(3) Rue Saint-Louis      Borne -75.723960  45.464412
#
# [345503 rows x 5 columns]

# %%
# Création du champ combiné
df["location_point"] = df["latitude"].astype(str) + "," + df["longitude"].astype(str)

# Vérification rapide
print(df[["latitude", "longitude", "location_point"]].head())
df
# Out:
#     latitude  longitude        location_point
# 0  45.489893 -75.720493  45.489893,-75.720493
# 1  45.490631 -75.721708  45.490631,-75.721708
# 2  45.490147 -75.721607  45.490147,-75.721607
# 3  45.490596 -75.721519  45.490596,-75.721519
# 4  45.490386 -75.720391  45.490386,-75.720391
#         adresseid         adresse_complete type_point  longitude   latitude  \
# 0             197        88 Rue de Lacaune    Adresse -75.720493  45.489893
# 1             198       115 Rue de Lacaune    Adresse -75.721708  45.490631
# 2             199       112 Rue de Lacaune    Adresse -75.721607  45.490147
# 3             200       111 Rue de Lacaune    Adresse -75.721519  45.490596
# 4             282        87 Rue de Lacaune    Adresse -75.720391  45.490386
# ...           ...                      ...        ...        ...        ...
# 345498      99808  1721(3) Rue Saint-Louis      Borne -75.723148  45.465320
# 345499      99808  1721(3) Rue Saint-Louis      Borne -75.723960  45.464412
# ...

# %%
df.to_csv("v_map_points_simple2.csv", index=False)
